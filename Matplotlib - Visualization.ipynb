# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('https://ibm.box.com/shared/static/lw190pt9zpy5bd1ptyg2aw15awomz9pu.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skip_footer=2
                      )
# Out:
# /home/user/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py:178: FutureWarning: the 'skip_footer' keyword is deprecated, use 'skipfooter' instead
#   return func(*args, **kwargs)

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...   2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...   2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...   1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...   3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...      0     0     1
# 4  Southern Europe  901   Developed regions     0  ...      0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.drop(['Type','Coverage','AREA','REG','DEV'],axis = 1,inplace = True)

# %%
df.rename(columns = {'OdName':'Country','AreaName':'Continent','Regname':'Region'},inplace = True)

# %%
df.set_index('Country',inplace = True)

# %%
df.head()
# Out:
#                Continent          RegName             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...   2004  2005  2006  2007  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...   2978  3436  3009  2652
# Albania            0     0     0     0     1  ...   1450  1223   856   702
# Algeria           71    69    63    44    69  ...   3616  3626  4807  3623
# American Samoa     0     0     0     0     0  ...      0     0     1     0
# Andorra            0     0     0     0     2  ...      0     0     1     1
#
# ...

# %%
df['Total'] = df.sum(axis = 1)

# %%
df.sort_values(['Total'],ascending = False,inplace = True,axis = 0)

# %%
df_top = df.head()

# %%
df_top
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                RegName  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
years = list(map(str,range(1980,2014)))

# %%
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
df_top.columns
# Out:
# Index(['Continent',   'RegName',   'DevName',        1980,        1981,
#               1982,        1983,        1984,        1985,        1986,
#               1987,        1988,        1989,        1990,        1991,
#               1992,        1993,        1994,        1995,        1996,
#               1997,        1998,        1999,        2000,        2001,
#               2002,        2003,        2004,        2005,        2006,
#               2007,        2008,        2009,        2010,        2011,
#               2012,        2013,     'Total'],
#       dtype='object')

# %%
year = list(range(1980,2014))

# %%
year
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
df_top
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                RegName  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
df_top.columns = list(map(str,df_top.columns))

# %%
df_top = df_top[years].transpose()

# %%
df_top
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
# 1985      4211   1816                                               9564
# 1986      7150   1960                                               9470
# 1987     10189   2643                                              21337
# 1988     11522   2758                                              27359
# 1989     10343   4323                                              23795
# 1990     12041   8076                                              31668
# 1991     13734  14255                                              23380
# ...

# %%
# %matplotlib notebook

# %%
ax = df_top.plot(kind = 'area',figsize=(10,5),stacked = False)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.title('Trends')
# Out:
# Text(0.5,1,'Trends')

# %%
plt.xlabel('Years')
plt.ylabel('Number of Immigrants')
# Out:
# Text(65.7222,0.5,'Number of Immigrants')

# %%
plt.show()

# %%
np.histogram(df[2013])
# Out:
# (array([178,  11,   1,   2,   0,   0,   0,   0,   1,   2]),
#  array([    0. ,  3412.9,  6825.8, 10238.7, 13651.6, 17064.5, 20477.4,
#         23890.3, 27303.2, 30716.1, 34129. ]))

# %%
freq,bins = np.histogram(df[2013])

# %%
df[2013].plot(kind = 'hist',xticks = bins)

# %%
df.loc[['India','China','Pakistan'],np.arange(1980,2014)].plot(kind = 'hist')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df_p2 = df.loc[['China','India','Pakistan'],np.arange(1980,2014)].transpose()

# %%
df_p2.head()
# Out:
# Country  China  India  Pakistan
# 1980      5123   8880       978
# 1981      6682   8670       972
# 1982      3308   8147      1201
# 1983      1863   7338       900
# 1984      1527   5704       668

# %%
df_p2.plot(kind = 'hist')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
freq2,bins2 = np.histogram(df_p2,15)

# %%
bins2
# Out:
# array([  514.        ,  3318.66666667,  6123.33333333,  8928.        ,
#        11732.66666667, 14537.33333333, 17342.        , 20146.66666667,
#        22951.33333333, 25756.        , 28560.66666667, 31365.33333333,
#        34170.        , 36974.66666667, 39779.33333333, 42584.        ])

# %%
df_il = df.loc['Iceland',np.arange(1980,2014)]

# %%
df_il.tail()
# Out:
# 2009    15
# 2010    30
# 2011    38
# 2012    42
# 2013    72
# Name: Iceland, dtype: object

# %%
# %matplotlib inline
