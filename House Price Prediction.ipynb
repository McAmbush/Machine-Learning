# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
features = ['sqft_living','sqft_above','grade','bathrooms','sqft_living15']

# %%
X = df[features]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sn

# %%
Y = df[['price']]

# %%
plt.figure(figsize = (10,5))
plt.scatter(X['sqft_living'],Y)

# %%
sn.regplot(X['sqft_living'],Y['price'])

# %%
X.head()
# Out:
#    sqft_living  sqft_above  grade  bathrooms  sqft_living15
# 0         1180        1180      7       1.00           1340
# 1         2570        2170      7       2.25           1690
# 2          770         770      6       1.00           2720
# 3         1960        1050      7       3.00           1360
# 4         1680        1680      8       2.00           1800

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
scaler = StandardScaler()

# %%
x = scaler.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
train_x,test_x,train_y,test_y = train_test_split(x,Y,test_size = 0.2)

# %%
lr.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr_pred = lr.predict(test_x)

# %%
print(r2_score(lr_pred,test_y))
# Out:
# 0.19454310396292263

# %%
print(mean_squared_error(lr_pred,test_y))
# Out:
# 60090676728.60654

# %%
poly = PolynomialFeatures(degree = 2)

# %%
x_pl = poly.fit_transform(train_x)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(x_pl,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
test_x_pl = poly.fit_transform(test_x)

# %%
pl_pred = lr2.predict(test_x_pl)

# %%
print(r2_score(test_y,pl_pred))
# Out:
# 0.5826960563485113

# %%
print(mean_squared_error(test_y,pl_pred))
# Out:
# 56253003457.045235
